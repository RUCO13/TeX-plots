# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
import subprocess, os
x = np.arange(-10,10,0.2)

yf = lambda x: np.sin(x)/(x)
y = np.array([yf(x[j]) for j in range(len(x))])

expdata = np.zeros((len(x),2))
expdata[:,0]=x
expdata[:,1]=y
np.savetxt("data/test-data.dat",expdata,delimiter=',')

#plot data
fig,ax = plt.subplots(1,1,figsize=(5,8))
fig.set_facecolor('white')

ax.plot(x,y,'-ob',ms=7,mfc="w")
plt.show()

# %%
kv = {'data':'data/test-data.dat',
      'xlabel-user':'$x$',
      'ylabel-user':'$y$',
      'legen-user':'first plot'}
with open('simple-plot.tex','r') as splot:
    text = splot.read()
    for key, value in kv.items():
        text = text.replace(key, value)
    with open('simple-plot-new.tex', 'w') as output:
        output.write(text)
    
os.system("pdflatex -shell-escape -file-line-error -output-directory=build-ruco %s"%("simple-plot-new.tex"))
os.system("rm -R simple-plot-new.tex")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /media/labfiles/ruco/repos/TeX-plots/notebooks/simple-plots.ipynb Cell 2' in <cell line: 5>()
#       <a href='vscode-notebook-cell://ssh-remote%2B148.224.6.205/media/labfiles/ruco/repos/TeX-plots/notebooks/simple-plots.ipynb#ch0000001vscode-remote?line=0'>1</a> kv = {'data':'data/test-data.dat',
#       <a href='vscode-notebook-cell://ssh-remote%2B148.224.6.205/media/labfiles/ruco/repos/TeX-plots/notebooks/simple-plots.ipynb#ch0000001vscode-remote?line=1'>2</a>       'xlabel-user':'$x$',
#       <a href='vscode-notebook-cell://ssh-remote%2B148.224.6.205/media/labfiles/ruco/repos/TeX-plots/notebooks/simple-plots.ipynb#ch0000001vscode-remote?line=2'>3</a>       'ylabel-user':'$y$',
#       <a href='vscode-notebook-cell://ssh-remote%2B148.224.6.205/media/labfiles/ruco/repos/TeX-plots/notebooks/simple-plots.ipynb#ch0000001vscode-remote?line=3'>4</a>       'legen-user':'first plot'}
# ----> <a href='vscode-notebook-cell://ssh-remote%2B148.224.6.205/media/labfiles/ruco/repos/TeX-plots/notebooks/simple-plots.ipynb#ch0000001vscode-remote?line=4'>5</a> with open('simple-plot.tex','r') as splot:
#       <a href='vscode-notebook-cell://ssh-remote%2B148.224.6.205/media/labfiles/ruco/repos/TeX-plots/notebooks/simple-plots.ipynb#ch0000001vscode-remote?line=5'>6</a>     text = splot.read()
#       <a href='vscode-notebook-cell://ssh-remote%2B148.224.6.205/media/labfiles/ruco/repos/TeX-plots/notebooks/simple-plots.ipynb#ch0000001vscode-remote?line=6'>7</a>     for key, value in kv.items():
#
# FileNotFoundError: [Errno 2] No such file or directory: 'simple-plot.tex'

# %%
# !echo $PYTHONPATH
# Out:
# /media/labfiles/ruco/repos/cqws-codes/cqws-v2:/media/labfiles/lab-codes:/home/ruco/anaconda3/envs/ASE/bin:

# %%
# !pwd
# Out:
# /media/labfiles/ruco/repos/TeX-plots/notebooks
